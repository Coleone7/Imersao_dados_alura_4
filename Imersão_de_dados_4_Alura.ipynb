# %%
import pandas as pd

url = ("https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv")

dados = pd.read_csv(url)

# %%
dados.head()
 #imprimir somente o cabeçalho.
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados #imprimir.
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10006         Rua Manuel Onha, , 514        Vila Oratório  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas  \
# 0          1000        4          8      6
# 1           496        4          4      4
# ...

# %%
dados.sample(10) #como puxar uma quantidade de amostra aleatoria.
# Out:
#                              Rua            Bairro     Cidade  Metragem  \
# 6747  Rua Joaquim Lima de Moraes       Santo Amaro  São Paulo       224
# 2369                 Rua Maracaí         Aclimação  São Paulo       420
# 2995    Rua Trinta e Um de Março   Fazenda Morumbi  São Paulo      1405
# 9126     Avenida Afrânio Peixoto           Butantã  São Paulo       313
# 7420                         NaN       Jardim Peri  São Paulo       335
# 5552          Rua dos Povoadores     Vila Antonina  São Paulo       167
# 6569                         NaN  Jardim Prudência  São Paulo       137
# 813      Rua Marechal Bitencourt   Jardim Paulista  São Paulo       360
# 8274                         NaN     Jardim Taboão  São Paulo       125
# 7830        Praça Santos Coimbra           Morumbi  São Paulo       550
#
#       Quartos  Banheiros  Vagas                                  Valor
# 6747        3          5      2                           R$ 1.500.000
# ...

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
dados["Rua"] #somente uma coluna. (funciona também como dados.Rua)
# Out:
# 0                 Avenida Itacira, 255
# 1        Rua Aurelia Perez Alvarez, 42
# 2                       Rua Alba Valdez
# 3                                   NaN
# 4              Rua Tobias Barreto, 195
#                       ...
# 10003                        Rua Tapuçu
# 10004                     Rua Guararema
# 10005                 Rua Estero Belaco
# 10006           Rua Manuel Onha, , 514
# 10007        Rua Barão de Tramandaí, 0
# Name: Rua, Length: 10008, dtype: object

# %%
dados['Bairro'][6522] #selecionar primeiro uma coluna especifica, depois uma linha especifica.
# Out:
# 'Vila Paulo Silas'

# %%
dados.info() #informações dos dados, pra saber se é string, ou não (Dtype). qtd de colunas, linhas etc.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados.Metragem.mean() #média da coluna Metragem
# Out:
# 442.30065947242207

# %%
dados["Metragem"].mean() #outra maneira de escrever
# Out:
# 442.30065947242207

# %%
dados["Bairro"] == "Vila Mariana" #select pra descobrir onde "Vila Mariana" existe na coluna "Bairro"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Bairro, Length: 10008, dtype: bool

# %%
sum((dados["Bairro"] == "Vila Mariana")*1)  #select pra verificar se existe algum valor verdadeiro na tabela gerada acima.
# Out:
# 184

# %%
tem_imoveis_vila = (dados["Bairro"] == "Vila Mariana")

# %%
imoveis = dados[tem_imoveis_vila]

# %%
imoveis.head
# Out:
# <bound method NDFrame.head of                                Rua        Bairro     Cidade  Metragem  \
# 100               Rua Pero Correia  Vila Mariana  São Paulo       250
# 120   Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250
# 155     Rua Professor João Marinho  Vila Mariana  São Paulo       170
# 160                            NaN  Vila Mariana  São Paulo       228
# 334         Rua Pero Correia, 892   Vila Mariana  São Paulo       350
# ...                            ...           ...        ...       ...
# 9645               Rua Sousa Ramos  Vila Mariana  São Paulo       285
# 9701             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9737             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9807                           NaN  Vila Mariana  São Paulo       275
# 9852              Rua França Pinto  Vila Mariana  São Paulo       280
#
#       Quartos  Banheiros  Vagas         Valor
# 100         3          3      1  R$ 1.350.000
# ...

# %%
imoveis.Metragem.mean() #imoveis["Metragem"].mean() também funciona.
# Out:
# 233.6195652173913

# %%
dados["Bairro"].value_counts() #a quantidade de vezes que a informação dentro da coluna "Bairro" se repete. Ex: Alto de Pinheiros, aparece 409 vezes.
# Out:
# Alto de Pinheiros     409
# Jardim Guedala        403
# Jardim Paulista       309
# Brooklin Paulista     247
# Jardim Europa         240
#                      ...
# Jardim das Imbuias      1
# Vila Represa            1
# Vila Nancy              1
# Sítio Represa           1
# Vila Invernada          1
# Name: Bairro, Length: 701, dtype: int64

# %%
n_imoveis_bairro = dados["Bairro"].value_counts() #designei o select acima como uma variavel.

n_imoveis_bairro.plot.bar() #setei um comando para imprimir um grafico da variavel acima. sintaxe [ variavel.plot.tipodegrafico ]

# %%
n_imoveis_bairro.head(10).plot.bar() #inseri um head como no começo, para pegar os 10 primeiros bairros.

# %%
########################################### Desafios:

#1 - Realizar a média da metragem para cada um dos bairros (Paulo)

#2 - 2 formas de selecionar os dados por bairro (consultar os métodos na documentação do pandas) (Thiago)

#3 - Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF, tentar colocar alguma conclusão (Thiago)

#4 - Pegar outros estatísticas dos dados, média, mediana, mim, max (Vivi)

#5 - Descobrir quais são os bairros que não tem nome de Rua. (Vivi)

# %%
######################################################################################################################################### DESAFIO 1 e 3 
#1 - Realizar a média da metragem para cara um dos bairros (Paulo)
#3 - Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF, tentar colocar alguma conclusão (Thiago)

metragem_bairro = dados.groupby('Bairro')['Metragem'].mean() 
metragem_bairro.head(20)
## média FEITA.
# Out:
# Bairro
# Aclimação                    253.056818
# Alto da Boa Vista            418.875000
# Alto da Lapa                 294.337209
# Alto da Mooca                270.050000
# Alto de Pinheiros            433.444988
# Aricanduva                   278.000000
# Balneário Mar Paulista       250.000000
# Barra Funda                  135.444444
# Barro Branco (Zona Norte)    489.000000
# Bela Aliança                 345.476190
# Bela Vista                   190.000000
# Belenzinho                   215.692308
# Boaçava                      512.026087
# Bom Retiro                   336.500000
# Bortolândia                  151.666667
# Bosque da Saúde              247.592593
# Brasilândia                   83.750000
# Brooklin                     339.416667
# Brooklin Novo                290.300000
# Brooklin Paulista            323.676113
# Name: Metragem, dtype: float64

# %%
metragem_bairro.head(20).plot.bar()
#imprimi a média quadrada dos bairros. mas não achei conveniente estar embaralhado. então dei um jeito de ordenar.

# %%
metragem_bairro_ordenado = metragem_bairro.sort_values(ascending=False)

metragem_bairro_ordenado.head(20).plot.barh() 

#### aparentemente um bairro tem valores quebrados.

# %%
metragem_bairro_ordenado.head(20)
# Out:
# Bairro
# Sítio Represa                   37000.000000
# Vila Castelo                     2850.000000
# Jardim Guedala                   2486.640199
# Jardim das Camélias              1700.000000
# Chácara Flora                    1260.727273
# Jardim Sílvia (Zona Oeste)       1189.258065
# Retiro Morumbi                   1084.045455
# Vila Aurora (Zona Norte)         1082.500000
# Paineiras do Morumbi              757.266667
# Vila Ivone                        722.500000
# Jardim Ipanema (Zona Oeste)       710.000000
# Jardim Everest                    704.431818
# Fazenda Morumbi                   700.028169
# Jardim Petropolis                 700.000000
# Cidade Jardim                     697.334783
# Jardim América                    672.094675
# Vila Tramontano                   668.924528
# Jardim Teresa                     648.333333
# Jardim Vitória Régia              644.142857
# Jardim Vera Cruz(Zona Leste)      642.500000
# Name: Metragem, dtype: float64

# %%
metragem_bairro_ordenado2 = metragem_bairro.sort_values(ascending=True)

metragem_bairro_ordenado2.head(10).plot.barh() 

#resolvi então inverter a ordenação.

# %%
######################################################################################################################################### DESAFIO 2
#2 formas de selecionar os dados por bairro (consultar os métodos na documentação do pandas) (Thiago)

bairros_agrupamento = dados.groupby("Bairro") #por groupby

bairros_agrupamento.head(10)
# Out:
#                                   Rua                 Bairro     Cidade  \
# 0               Avenida Itacira, 255       Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42      Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez        Jardim Reimberg  São Paulo
# 3                                 NaN         Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                   Mooca  São Paulo
# ...                               ...                    ...        ...
# 9993          Rua Frei Mauro Teixeira       Jardim São Bento  São Paulo
# 9996               Rua Aquino Fonseca  Jardim das Carmelitas  São Paulo
# 9998                 Rua Eduardo Lobo        Parque Imperial  São Paulo
# 10003                      Rua Tapuçu             Vila Sofia  São Paulo
# 10007      Rua Barão de Tramandaí, 0             Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor
# ...

# %%
###por seleção e condição 
bairro_teste = "Jardim Morumbi"            
dados[dados["Bairro"] == bairro_teste]
# Out:
#                                                     Rua          Bairro  \
# 3                                                   NaN  Jardim Morumbi
# 361                                                 NaN  Jardim Morumbi
# 408                                                 NaN  Jardim Morumbi
# 415                                                 NaN  Jardim Morumbi
# 618                         Rua Doutor Jesuíno de Abreu  Jardim Morumbi
# 634                         Rua Doutor Jesuíno de Abreu  Jardim Morumbi
# 694                       Rua Senador Otávio Mangabeira  Jardim Morumbi
# 720       Rua Doutor Manuel Carlos de Figueiredo Ferraz  Jardim Morumbi
# 762                     Rua Professor Luciano Gualberto  Jardim Morumbi
# 785                     Rua Professor Luciano Gualberto  Jardim Morumbi
# 818                     Rua Professor Luciano Gualberto  Jardim Morumbi
# 841                     Rua Professor Luciano Gualberto  Jardim Morumbi
# ...

# %%
## Desafio 3

#4 - Pegar outros estatísticas dos dados, média, mediana, mim, max (Vivi)

media_b = dados["Banheiros"].mean()
print("Média de banheiros:", media_b)

mediana_b = dados["Banheiros"].median() 
print("Mediana de banheiros:", mediana_b)

max_b = dados["Banheiros"].max()
print("Máximo de banheiros em um imóvel:", max_b)

max_b = dados["Banheiros"].idxmax()  

min_b = dados["Banheiros"].min() 
print("Mínimo de banheiros num imóvel: ", min_b)

moda_b = dados["Banheiros"].mode()
print("Moda de banheiros:", moda_b)
# Out:
# Média de banheiros: 3.8790967226219024
# Mediana de banheiros: 4.0
# Máximo de banheiros em um imóvel: 40
# Mínimo de banheiros num imóvel:  1
# Moda de banheiros: 0    3
# dtype: int64

# %%
######### Desafio

#5 - Descobrir quais são os bairros que não tem nome de Rua. (Vivi)

dados[dados["Rua"].isna()] #ruas que não possuem informação
# Out:
#       Rua                            Bairro     Cidade  Metragem  Quartos  \
# 3     NaN                    Jardim Morumbi  São Paulo       310        3
# 11    NaN                  Jardim Luzitânia  São Paulo       436        4
# 31    NaN                    Parque da Lapa  São Paulo       220        4
# 56    NaN  Chácara Santo Antônio (Zona Sul)  São Paulo       190        2
# 57    NaN                    Jardim Guedala  São Paulo       650        4
# ...   ...                               ...        ...       ...      ...
# 9963  NaN                 Jardim Petrópolis  São Paulo       423        5
# 9989  NaN              Parque Alves de Lima  São Paulo       127        2
# 9991  NaN                      Vila Formosa  São Paulo       145        3
# 9995  NaN                     Jardim Leonor  São Paulo      1350        5
# 9999  NaN                 Jardim Petrópolis  São Paulo       423        5
#
#       Banheiros  Vagas         Valor
# 3             2      4    R$ 685.000
# ...

# %%
dados[dados["Rua"].isna()]["Bairro"] #bairros que possuem informações sem rua.
# Out:
# 3                         Jardim Morumbi
# 11                      Jardim Luzitânia
# 31                        Parque da Lapa
# 56      Chácara Santo Antônio (Zona Sul)
# 57                        Jardim Guedala
#                       ...
# 9963                   Jardim Petrópolis
# 9989                Parque Alves de Lima
# 9991                        Vila Formosa
# 9995                       Jardim Leonor
# 9999                   Jardim Petrópolis
# Name: Bairro, Length: 3434, dtype: object

# %%
##### Para o tratamento de dados da aula 2, vo no discord um colega que compartilho outro metodo para tratar os dados. 
# Nele, em vez de separar a string em várias colunas e tratar somente os numeros, ele "excluiu" todos os outros caracteres indesejados da coluna e deixou somente os numeros.

#dados["Valor"] = dados["Valor"].str.replace("R$ ","", regex=False) # Aqui removemos o R$ e o espaço a frente dele
# dados.Valor = dados.Valor.str.replace(".", "", regex=False) # Aqui removemos os pontos de milhares (.)
# dados.Valor.sample(30) # Aqui fazemos uma amostragem de 30 elementos para ver a formatação
# dados.Valor = dados.Valor.str.replace("\n                      /Mês","", regex=False) # aqui removemos a string (texto) "\n                      /Mês"
# dados.Valor = dados.Valor.str.replace("\n                      /Ano","", regex=False) # aqui removemos a string (texto) "\n                      /Ano"
# dados.Valor = dados.Valor.str.replace("\n                      /Dia","", regex=False) # aqui removemos a string (texto) "\n                      /Dia"
# dados.Valor = dados.Valor.astype(float) # Finalmente convertemos a coluna Valor de object para o formato Float (número decimal)
# dados.info() # Após a conversão checamos o DataFrame com o comando .info() e verificamos que a coluna "Valor" agora é do tipo Float64

#credito para: https://github.com/Mestevam1976/imersao_dados_alura_4_edicao/blob/main/Aula%202/Imers%C3%A3o_de_Dados_Alura_M%C3%A1rcio_Aula_2.ipynb

# %%
########### Aula 2
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados["Valor"][0] #peguei somente a celular da linha 0 da coluna valor.
# Out:
# 'R$ 7.000.000'

# %%
dados["Valor"][0].split() #split quebrou a informação em duas partes. separa tudo por "espaço"
# Out:
# ['R$', '7.000.000']

# %%
dados["Valor"].str.split(expand = True) #transformou a split quebrada por espaço em uma tabela.
# Out:
#         0          1     2
# 0      R$  7.000.000  None
# 1      R$  3.700.000  None
# 2      R$    380.000  None
# 3      R$    685.000  None
# 4      R$    540.000  None
# ...    ..        ...   ...
# 10003  R$    665.000  None
# 10004  R$  2.300.000  None
# 10005  R$  1.050.000  None
# 10006  R$      2.200  /Mês
# 10007  R$    270.000  None
#
# [10008 rows x 3 columns]

# %%
dados["Valor"].str.split(expand = True)[0].unique()  #se colocar "len" no começo, mostra os itens que repetem.
# Out:
# array(['R$'], dtype=object)

# %%
dados[["Valor", "Bairro"]] #PARA PUXAR DUAS COLUNAS, USAR DOIS COLCHETES [[]]
# Out:
#                                       Valor              Bairro
# 0                              R$ 7.000.000   Planalto Paulista
# 1                              R$ 3.700.000  Jardim dos Estados
# 2                                R$ 380.000     Jardim Reimberg
# 3                                R$ 685.000      Jardim Morumbi
# 4                                R$ 540.000               Mooca
# ...                                     ...                 ...
# 10003                            R$ 665.000          Vila Sofia
# 10004                          R$ 2.300.000     Bosque da Saúde
# 10005                          R$ 1.050.000       Vila da Saúde
# 10006  R$ 2.200\n                      /Mês       Vila Oratório
# 10007                            R$ 270.000         Vila Alpina
#
# [10008 rows x 2 columns]

# %%
dados[["Moeda", "Valor_anuncio", "Tipo_anuncio"]] = dados["Valor"].str.split(expand = True)
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio Tipo_anuncio
# 0        4          8      6  R$ 7.000.000    R$     7.000.000         None
# 1        4          4      4  R$ 3.700.000    R$     3.700.000         None
# 2        4          3      2    R$ 380.000    R$       380.000         None
# 3        3          2      4    R$ 685.000    R$       685.000         None
# 4        3          2      2    R$ 540.000    R$       540.000         None

# %%
dados["Tipo_anuncio"].isnull()
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 10003     True
# 10004     True
# 10005     True
# 10006    False
# 10007     True
# Name: Tipo_anuncio, Length: 10008, dtype: bool

# %%
dados_vendas = dados[dados["Tipo_anuncio"].isnull()]
dados_vendas
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio  \
# ...

# %%
dados_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rua            6107 non-null   object
#  1   Bairro         9146 non-null   object
#  2   Cidade         9156 non-null   object
#  3   Metragem       9156 non-null   int64
#  4   Quartos        9156 non-null   int64
#  5   Banheiros      9156 non-null   int64
#  6   Vagas          9156 non-null   int64
#  7   Valor          9156 non-null   object
#  8   Moeda          9156 non-null   object
#  9   Valor_anuncio  9156 non-null   object
#  10  Tipo_anuncio   0 non-null      object
# dtypes: int64(4), object(7)
# memory usage: 858.4+ KB

# %%
dados_vendas["Valor_anuncio"].str.replace(".","").astype(float)   #alterou o "." por vazio ("").
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# 0        7000000.0
# 1        3700000.0
# 2         380000.0
# 3         685000.0
# 4         540000.0
#            ...
# 10002    1500000.0
# 10003     665000.0
# 10004    2300000.0
# 10005    1050000.0
# 10007     270000.0
# Name: Valor_anuncio, Length: 9156, dtype: float64

# %%
dados_vendas["Valor_anuncio_float"] = dados_vendas["Valor_anuncio"].str.replace(".","").astype(float)  #comando adicionando uma coluna com as informações do select acima.
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dados_vendas.info() # a coluna foi adicionada e tem o Dtype float64.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rua                  6107 non-null   object
#  1   Bairro               9146 non-null   object
#  2   Cidade               9156 non-null   object
#  3   Metragem             9156 non-null   int64
#  4   Quartos              9156 non-null   int64
#  5   Banheiros            9156 non-null   int64
#  6   Vagas                9156 non-null   int64
#  7   Valor                9156 non-null   object
#  8   Moeda                9156 non-null   object
#  9   Valor_anuncio        9156 non-null   object
#  10  Tipo_anuncio         0 non-null      object
#  11  Valor_anuncio_float  9156 non-null   float64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 929.9+ KB

# %%
dados_vendas["Valor_anuncio_float"].plot.hist(bins = 50)  #.plot.hist é um imprimir/plotar.tipoDoGrafico

# %%
dados_vendas.describe()
# Out:
#             Metragem      Quartos    Banheiros        Vagas  \
# count    9156.000000  9156.000000  9156.000000  9156.000000
# mean      434.416230     3.446811     3.797073     3.960135
# std      7856.422978     1.048944     1.967873     2.601022
# min        10.000000     1.000000     1.000000     1.000000
# 25%       168.000000     3.000000     2.000000     2.000000
# 50%       276.000000     3.000000     4.000000     4.000000
# 75%       450.000000     4.000000     5.000000     5.000000
# max    750000.000000    16.000000    40.000000    50.000000
#
#        Valor_anuncio_float
# count         9.156000e+03
# mean          3.052203e+06
# std           3.944208e+06
# min           1.300000e+04
# 25%           8.900000e+05
# 50%           1.800000e+06
# 75%           3.500000e+06
# max           6.500000e+07

# %%
###### DESAFIO AULA 2
# criar uma escala de valores em milhões.

# %%
pd.set_option("display.precision", 2)
pd.set_option("display.float_format", lambda x:'%.2f' %x)
dados_vendas.describe()
# Out:
#        Metragem  Quartos  Banheiros   Vagas  Valor_anuncio_float
# count   9156.00  9156.00    9156.00 9156.00              9156.00
# mean     434.42     3.45       3.80    3.96           3052202.96
# std     7856.42     1.05       1.97    2.60           3944208.19
# min       10.00     1.00       1.00    1.00             13000.00
# 25%      168.00     3.00       2.00    2.00            890000.00
# 50%      276.00     3.00       4.00    4.00           1800000.00
# 75%      450.00     4.00       5.00    5.00           3500000.00
# max   750000.00    16.00      40.00   50.00          65000000.00

# %%
dados_vendas.describe(include = "all")
# Out:
#                       Rua             Bairro     Cidade  Metragem  Quartos  \
# count                6107               9146       9156   9156.00  9156.00
# unique               3006                697          1       NaN      NaN
# top     Rua Alberto Faria  Alto de Pinheiros  São Paulo       NaN      NaN
# freq                   24                369       9156       NaN      NaN
# mean                  NaN                NaN        NaN    434.42     3.45
# std                   NaN                NaN        NaN   7856.42     1.05
# min                   NaN                NaN        NaN     10.00     1.00
# 25%                   NaN                NaN        NaN    168.00     3.00
# 50%                   NaN                NaN        NaN    276.00     3.00
# 75%                   NaN                NaN        NaN    450.00     4.00
# max                   NaN                NaN        NaN 750000.00    16.00
#
# ...

# %%
dados_vendas[["Rua", "Bairro", "Cidade"]].describe()
# Out:
#                       Rua             Bairro     Cidade
# count                6107               9146       9156
# unique               3006                697          1
# top     Rua Alberto Faria  Alto de Pinheiros  São Paulo
# freq                   24                369       9156

# %%
import seaborn as sns  # o seaborn (sns) está sendo utilizado para montar o grafico. 
import matplotlib.pyplot as plt #o matplotlib(plt) está sendo utilizado para edição do desing no grafico.

sns.set()
plt.figure(figsize=(10,8))  #comando do plt para configurar o tamanho do grafico
ax = sns.histplot(data = dados_vendas, x = "Valor_anuncio_float", kde=True)   #no eixo X, setamos a coluna que queremos plotar
ax.set_title("Histograma Valor Imóvel") #comando para alterar o titulo do grafico
plt.xlim((-50, 10000000)) #comando para alterar a escala.
plt.show()

# %%
#Desafio Aula 2
#Criar uma escala de valores em milhões
#Deixar o gráfico do histograma de valores legível (alterar labels, cores, título, escala)
#Preço do metro quadrado por bairro e plotar em um gráfico ideal
#Explorar as bibliotecas de visualizações e colocar as suas conclusão
#Pesquisar um visualização para analisar os quartis, mediana e outliers

# %%
dados.Valor.str.split(expand=True)
valores = dados.Valor.str.split(expand=True)
valores.head()
# Out:
#     0          1     2
# 0  R$  7.000.000  None
# 1  R$  3.700.000  None
# 2  R$    380.000  None
# 3  R$    685.000  None
# 4  R$    540.000  None

# %%
dados[["moeda", "qtd", "modal"]] = valores

# %%
dados1 = dados[dados["modal"].isnull()]
dados1.qtd.str.replace(".","").astype(float)
dados1.qtd = dados1.qtd.str.replace(".","").astype(float)
dados1.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
1 #Criar uma escala de valores em milhões 

dados1.qtd = dados1.qtd/1000000


dados1.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio Tipo_anuncio  \
# ...

# %%
##################################### DESAFIO 2 
#Deixar o gráfico do histograma de valores legível (alterar labels, cores, título, escala)
import seaborn as sns  
import matplotlib.pyplot as plt 

sns.set()
plt.figure(figsize=(10,8))
ax = sns.histplot(data = dados1, x = "qtd", color = "red", kde=True)
ax.set_title("Histograma Valor Imóvel")
plt.xlim((1,10)) #exclui o primeiro imovel para retirar o extremo.
plt.xlabel("Valor (milhões de reais)")
plt.ylabel("QTD de imóveis")
plt.show()

# %%
##################################### DESAFIO 3
#Preço do metro quadrado por bairro e plotar em um gráfico ideal

dados1[['Bairro', "Metragem", "qtd"]].groupby("Bairro", as_index=False).mean()

valor_metro = dados1[['Bairro', "Metragem", "qtd"]].groupby("Bairro", as_index=False).mean()

valor_metro.head()
# Out:
#               Bairro  Metragem  qtd
# 0          Aclimação    246.16 1.76
# 1  Alto da Boa Vista    418.88 2.39
# 2       Alto da Lapa    299.25 2.08
# 3      Alto da Mooca    270.05 1.18
# 4  Alto de Pinheiros    429.85 4.78

# %%
valor_metro["valor/m²"] = valor_metro["qtd"]/valor_metro["Metragem"]
valor_metro["valor/m²"] = valor_metro["valor/m²"]*1000000
valor_metro.head()
# Out:
#               Bairro  Metragem  qtd  valor/m²
# 0          Aclimação    246.16 1.76   7162.69
# 1  Alto da Boa Vista    418.88 2.39   5708.74
# 2       Alto da Lapa    299.25 2.08   6961.30
# 3      Alto da Mooca    270.05 1.18   4385.00
# 4  Alto de Pinheiros    429.85 4.78  11126.34

# %%
sns.set_style("white")
loc4 = plt.MultipleLocator(base=100)
plt.figure(figsize = (12,6))
plt.xlim(0.2, 6)
plt.ylim(0, 1000)
plt.xlabel("Valor em milhões")
plt.ylabel("Dimensão em m² ")
bx = sns.scatterplot(x=valor_metro["qtd"], y=valor_metro["Metragem"], hue = valor_metro["Bairro"])
bx.set_title("Dispersão da média de metros por preço de imóveis nos bairros da cidade de SP")
bx.get_legend().remove()

# %%
dados_vendas["Valor/m²"] = dados_vendas["Valor_anuncio_float"]/dados_vendas["Metragem"] ## criei uma coluna com o valor da metragem quadrada.
dados_vendas.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio Tipo_anuncio  \
# ...

# %%
dados_vendas.groupby("Bairro").mean() ###groupby é o comando que se usa para definir um agrupamento e depois definir oque irá ser feito. média, soma... etc.
# Out:
#                    Metragem  Quartos  Banheiros  Vagas  Valor_anuncio_float  \
# Bairro
# Aclimação            246.16     3.27       3.04   2.91           1763200.01
# Alto da Boa Vista    418.88     4.12       5.12   4.62           2391250.00
# Alto da Lapa         299.25     3.15       3.85   4.00           2083168.75
# Alto da Mooca        270.05     3.30       2.60   3.65           1184170.00
# Alto de Pinheiros    429.85     3.94       4.83   4.95           4782698.96
# ...                     ...      ...        ...    ...                  ...
# Vila Água Funda      152.20     2.60       2.20   2.60            652000.00
# Água Branca          173.58     3.08       3.25   2.25           1226500.00
# Água Fria            165.42     2.83       3.42   2.50            927083.33
# Água Funda           139.00     3.00       2.50   2.00            545000.00
# Água Rasa            186.17     2.67       2.00   3.67            716166.67
#
#                    Valor/m²
# Bairro
# ...

# %%
dados_bairro = dados_vendas.groupby("Bairro").sum() 
dados_bairro.head()
# Out:
#                    Metragem  Quartos  Banheiros  Vagas  Valor_anuncio_float  \
# Bairro
# Aclimação             19447      258        240    230         139292801.00
# Alto da Boa Vista      3351       33         41     37          19130000.00
# Alto da Lapa          23940      252        308    320         166653500.00
# Alto da Mooca          5401       66         52     73          23683400.00
# Alto de Pinheiros    158616     1453       1782   1827        1764815915.00
#
#                     Valor/m²
# Bairro
# Aclimação          604837.39
# Alto da Boa Vista   46796.55
# Alto da Lapa       608538.25
# Alto da Mooca      113834.80
# Alto de Pinheiros 4158622.61

# %%
dados_bairro["valor_m2_bairro"] = dados_bairro["Valor_anuncio_float"]/dados_bairro["Metragem"]
dados_bairro
# Out:
#                    Metragem  Quartos  Banheiros  Vagas  Valor_anuncio_float  \
# Bairro
# Aclimação             19447      258        240    230         139292801.00
# Alto da Boa Vista      3351       33         41     37          19130000.00
# Alto da Lapa          23940      252        308    320         166653500.00
# Alto da Mooca          5401       66         52     73          23683400.00
# Alto de Pinheiros    158616     1453       1782   1827        1764815915.00
# ...                     ...      ...        ...    ...                  ...
# Vila Água Funda         761       13         11     13           3260000.00
# Água Branca            2083       37         39     27          14718000.00
# Água Fria              1985       34         41     30          11125000.00
# Água Funda              278        6          5      4           1090000.00
# Água Rasa              1117       16         12     22           4297000.00
#
#                     Valor/m²  valor_m2_bairro
# ...

# %%
top_bairros=dados_vendas["Bairro"].value_counts()[:10].index #contando a quantidade de imoveis que os bairros tem vendendo

# %%
dados_bairro.reset_index(inplace = True)
dados_bairro
# Out:
#                 Bairro  Metragem  Quartos  Banheiros  Vagas  \
# 0            Aclimação     19447      258        240    230
# 1    Alto da Boa Vista      3351       33         41     37
# 2         Alto da Lapa     23940      252        308    320
# 3        Alto da Mooca      5401       66         52     73
# 4    Alto de Pinheiros    158616     1453       1782   1827
# ..                 ...       ...      ...        ...    ...
# 692    Vila Água Funda       761       13         11     13
# 693        Água Branca      2083       37         39     27
# 694          Água Fria      1985       34         41     30
# 695         Água Funda       278        6          5      4
# 696          Água Rasa      1117       16         12     22
#
#      Valor_anuncio_float   Valor/m²  valor_m2_bairro
# 0           139292801.00  604837.39          7162.69
# 1            19130000.00   46796.55          5708.74
# 2           166653500.00  608538.25          6961.30
# ...

# %%
dados_bairro.query("Bairro in @top_bairros")  #filtrando somente os bairros que existem na top_bairros.
# Out:
#                 Bairro  Metragem  Quartos  Banheiros  Vagas  \
# 4    Alto de Pinheiros    158616     1453       1782   1827
# 19   Brooklin Paulista     70002      778        862    832
# 57       Cidade Jardim    132220      789       1008   1172
# 155      Jardim Europa    118898      795        993   1056
# 168     Jardim Guedala    972212     1443       2027   2161
# 187      Jardim Leonor     97141      697        941    902
# 227    Jardim Paulista    130283     1028       1231   1171
# 338           Pacaembu    100285      774        889   1028
# 396  Planalto Paulista     59250      636        768    713
# 564      Vila Madalena     66250      739        786    712
#
#      Valor_anuncio_float   Valor/m²  valor_m2_bairro
# 4          1764815915.00 4158622.61         11126.34
# 19          475796789.00 1627341.87          6796.90
# 57         1164210900.00 1635692.98          8805.10
# 155        2414172900.00 4192164.45         20304.57
# ...

# %%
plt.figure(figsize=(10,8))
ax= sns.barplot(x="Bairro", y="valor_m2_bairro", data=dados_bairro.query("Bairro in @top_bairros")) #imprimindo a querry acima
ax.tick_params(axis='x', rotation=45)

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(data = dados_vendas.query("Bairro in @top_bairros"), x="Bairro", y="Valor_anuncio_float")
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(data = dados_vendas.query("Bairro in @top_bairros & Metragem < 30000"), x="Bairro", y="Metragem")
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
ibge_url = "https://gist.githubusercontent.com/tgcsantos/85f8c7b0a2edbc3e27fcad619b37d886/raw/a4954781e6bca9cb804062a3eea0b3b84679daf4/Basico_SP1.csv"
pd.read_csv(ibge_url)
# Out:
#                                                                                                                                                Cod_setor;Cod_Grandes Regi�es;Nome_Grande_Regiao;Cod_UF;Nome_da_UF ;Cod_meso;Nome_da_meso;Cod_micro;Nome_da_micro;Cod_RM;Nome_da_RM;Cod_municipio;Nome_do_municipio;Cod_distrito;Nome_do_distrito;Cod_subdistrito;Nome_do_subdistrito;Cod_bairro;Nome_do_bairro;Situacao_setor;Tipo_setor;V001;V002;V003;V004;V005;V006;V007;V008;V009;V010;V011;V012;
# 355030801000001;3;"Regi�o Sudeste";35;"S�o Paul... 01;2 32;2091 32;8532451           78;2164 55;8673276 78;1227 41;4285771 99;1713 75;5152087                                              86.00
# 355030801000002;3;"Regi�o Sudeste";35;"S�o Paul... 98;2 09;1650 09;3983441           31;1717 44;4030519 99;1045 78;2572133 32;1468 08;2991546                                              94.00
# ...

# %%
#Desafio Aula 3
#Tentar vincular dados do IBGE com os dados de imóveis.
#Tratar os outliers e comparar com os resultados.
#Agrupar por mais de uma categoria e realizar as análises.
#Organize o colab para deixar com cara de projeto.

# %%
import pandas as pd
ibge_sp = pd.read_csv(
    'https://gist.githubusercontent.com/tgcsantos/85f8c7b0a2edbc3e27fcad619b37d886/raw/a4954781e6bca9cb804062a3eea0b3b84679daf4/Basico_SP1.csv',
    encoding='ISO-8859-1',
    sep=';', thousands='.', decimal=','
)
ibge_sp.dropna(how='all', axis=1, inplace=True)
ibge_sp.head()
# Out:
#          Cod_setor  Cod_Grandes Regiï¿½es Nome_Grande_Regiao  Cod_UF  \
# 0  355030801000001                      3   Regiï¿½o Sudeste      35
# 1  355030801000002                      3   Regiï¿½o Sudeste      35
# 2  355030801000003                      3   Regiï¿½o Sudeste      35
# 3  355030801000004                      3   Regiï¿½o Sudeste      35
# 4  355030801000005                      3   Regiï¿½o Sudeste      35
#
#    Nome_da_UF   Cod_meso                  Nome_da_meso  Cod_micro  \
# 0  Sï¿½o Paulo      3515  Metropolitana de Sï¿½o Paulo      35061
# 1  Sï¿½o Paulo      3515  Metropolitana de Sï¿½o Paulo      35061
# 2  Sï¿½o Paulo      3515  Metropolitana de Sï¿½o Paulo      35061
# 3  Sï¿½o Paulo      3515  Metropolitana de Sï¿½o Paulo      35061
# 4  Sï¿½o Paulo      3515  Metropolitana de Sï¿½o Paulo      35061
#
#   Nome_da_micro  Cod_RM  ... V003  V004    V005       V006    V007       V008  \
# ...
